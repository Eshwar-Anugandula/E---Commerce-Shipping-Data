# %%
#imporing useful libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
from pydoc import help

# %%
#Reading the required data set

# %%
d=pd.read_csv("train.csv")

# %%
#displaying whole dataset
d
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 0          1               D           Flight                    4
# 1          2               F           Flight                    4
# 2          3               A           Flight                    2
# 3          4               B           Flight                    3
# 4          5               C           Flight                    2
# ...      ...             ...              ...                  ...
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                    2                  177                3
# 1                    5                  216                2
# 2                    2                  183                4
# 3                    3                  176                4
# 4                    2                  184                3
# ...                ...                  ...              ...
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 0                    low      F                44           1233
# 1                    low      M                59           3088
# 2                    low      M                48           3374
# 3                 medium      M                10           1177
# 4                 medium      F                46           2484
# ...                  ...    ...               ...            ...
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 0                        1
# 1                        1
# 2                        1
# 3                        1
# 4                        1
# ...                    ...
# 10994                    1
# 10995                    0
# 10996                    0
# 10997                    0
# 10998                    0
#
# [10999 rows x 12 columns]

# %%
#displaying first 10 rows

# %%
d.head(10)
# Out:
#    ID Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0   1               D           Flight                    4                2
# 1   2               F           Flight                    4                5
# 2   3               A           Flight                    2                2
# 3   4               B           Flight                    3                3
# 4   5               C           Flight                    2                2
# 5   6               F           Flight                    3                1
# 6   7               D           Flight                    3                4
# 7   8               F           Flight                    4                1
# 8   9               A           Flight                    3                4
# 9  10               B           Flight                    3                2
#
#    Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                  177                3                low      F
# 1                  216                2                low      M
# 2                  183                4                low      M
# 3                  176                4             medium      M
# 4                  184                3             medium      F
# 5                  162                3             medium      F
# 6                  250                3                low      F
# 7                  233                2                low      F
# 8                  150                3                low      F
# 9                  164                3             medium      F
#
#    Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                44           1233                    1
# 1                59           3088                    1
# 2                48           3374                    1
# 3                10           1177                    1
# 4                46           2484                    1
# 5                12           1417                    1
# 6                 3           2371                    1
# 7                48           2804                    1
# 8                11           1861                    1
# 9                29           1187                    1

# %%
#displaying last 10 rows

# %%
d.tail(10)
# Out:
#           ID Warehouse_block Mode_of_Shipment  Customer_care_calls  \
# 10989  10990               B             Ship                    5
# 10990  10991               C             Ship                    5
# 10991  10992               F             Ship                    5
# 10992  10993               D             Ship                    5
# 10993  10994               F             Ship                    5
# 10994  10995               A             Ship                    4
# 10995  10996               B             Ship                    4
# 10996  10997               C             Ship                    5
# 10997  10998               F             Ship                    5
# 10998  10999               D             Ship                    2
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 10989                1                  218                5
# 10990                4                  219                6
# 10991                2                  261                5
# 10992                1                  236                5
# 10993                1                  257                6
# 10994                1                  252                5
# 10995                1                  232                5
# 10996                4                  242                5
# 10997                2                  223                6
# 10998                5                  155                5
#
#       Product_importance Gender  Discount_offered  Weight_in_gms  \
# 10989             medium      F                 9           1603
# 10990                low      M                 3           1098
# 10991             medium      M                 9           1227
# 10992             medium      M                 3           1906
# 10993                low      F                 1           1150
# 10994             medium      F                 1           1538
# 10995             medium      F                 6           1247
# 10996                low      F                 4           1155
# 10997             medium      M                 2           1210
# 10998                low      F                 6           1639
#
#        Reached.on.Time_Y.N
# 10989                    0
# 10990                    0
# 10991                    1
# 10992                    0
# 10993                    0
# 10994                    1
# 10995                    0
# 10996                    0
# 10997                    0
# 10998                    0

# %%
d.info() #details of all the columns present in the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10999 entries, 0 to 10998
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   10999 non-null  int64
#  1   Warehouse_block      10999 non-null  object
#  2   Mode_of_Shipment     10999 non-null  object
#  3   Customer_care_calls  10999 non-null  int64
#  4   Customer_rating      10999 non-null  int64
#  5   Cost_of_the_Product  10999 non-null  int64
#  6   Prior_purchases      10999 non-null  int64
#  7   Product_importance   10999 non-null  object
#  8   Gender               10999 non-null  object
#  9   Discount_offered     10999 non-null  int64
#  10  Weight_in_gms        10999 non-null  int64
#  11  Reached.on.Time_Y.N  10999 non-null  int64
# dtypes: int64(8), object(4)
# memory usage: 1.0+ MB

# %%
d.isnull() #checking if there is any null value or not.
# Out:
#           ID  Warehouse_block  Mode_of_Shipment  Customer_care_calls  \
# 0      False            False             False                False
# 1      False            False             False                False
# 2      False            False             False                False
# 3      False            False             False                False
# 4      False            False             False                False
# ...      ...              ...               ...                  ...
# 10994  False            False             False                False
# 10995  False            False             False                False
# 10996  False            False             False                False
# 10997  False            False             False                False
# 10998  False            False             False                False
#
#        Customer_rating  Cost_of_the_Product  Prior_purchases  \
# 0                False                False            False
# 1                False                False            False
# 2                False                False            False
# 3                False                False            False
# 4                False                False            False
# ...                ...                  ...              ...
# 10994            False                False            False
# 10995            False                False            False
# 10996            False                False            False
# 10997            False                False            False
# 10998            False                False            False
#
#        Product_importance  Gender  Discount_offered  Weight_in_gms  \
# 0                   False   False             False          False
# 1                   False   False             False          False
# 2                   False   False             False          False
# 3                   False   False             False          False
# 4                   False   False             False          False
# ...                   ...     ...               ...            ...
# 10994               False   False             False          False
# 10995               False   False             False          False
# 10996               False   False             False          False
# 10997               False   False             False          False
# 10998               False   False             False          False
#
#        Reached.on.Time_Y.N
# 0                    False
# 1                    False
# 2                    False
# 3                    False
# 4                    False
# ...                    ...
# 10994                False
# 10995                False
# 10996                False
# 10997                False
# 10998                False
#
# [10999 rows x 12 columns]

# %% [markdown]
# # Data Cleaning

# %%
#Droping the 'ID' since it is of no use
d.drop('ID', axis=1,inplace=True) 
#displaying the dataset again after removing the ID column
d
# Out:
#       Warehouse_block Mode_of_Shipment  Customer_care_calls  Customer_rating  \
# 0                   D           Flight                    4                2
# 1                   F           Flight                    4                5
# 2                   A           Flight                    2                2
# 3                   B           Flight                    3                3
# 4                   C           Flight                    2                2
# ...               ...              ...                  ...              ...
# 10994               A             Ship                    4                1
# 10995               B             Ship                    4                1
# 10996               C             Ship                    5                4
# 10997               F             Ship                    5                2
# 10998               D             Ship                    2                5
#
#        Cost_of_the_Product  Prior_purchases Product_importance Gender  \
# 0                      177                3                low      F
# 1                      216                2                low      M
# 2                      183                4                low      M
# 3                      176                4             medium      M
# 4                      184                3             medium      F
# ...                    ...              ...                ...    ...
# 10994                  252                5             medium      F
# 10995                  232                5             medium      F
# 10996                  242                5                low      F
# 10997                  223                6             medium      M
# 10998                  155                5                low      F
#
#        Discount_offered  Weight_in_gms  Reached.on.Time_Y.N
# 0                    44           1233                    1
# 1                    59           3088                    1
# 2                    48           3374                    1
# 3                    10           1177                    1
# 4                    46           2484                    1
# ...                 ...            ...                  ...
# 10994                 1           1538                    1
# 10995                 6           1247                    0
# 10996                 4           1155                    0
# 10997                 2           1210                    0
# 10998                 6           1639                    0
#
# [10999 rows x 11 columns]

# %%
#Renaming last column
d.rename(columns={'Reached.on.Time_Y.N':'Reached_on_Time_Yes_No'}, inplace=True)

# %%
#checking if there is any null value and counting all the null values according to a particular row
x=d.isnull().sum() 
x
# Out:
# Warehouse_block           0
# Mode_of_Shipment          0
# Customer_care_calls       0
# Customer_rating           0
# Cost_of_the_Product       0
# Prior_purchases           0
# Product_importance        0
# Gender                    0
# Discount_offered          0
# Weight_in_gms             0
# Reached_on_Time_Yes_No    0
# dtype: int64

# %%
x.plot.bar()
plt.title("count of null values in each columns")
plt.show()

# %% [markdown]
# #### Descriptive Statistics Summary

# %%
d.describe()
# Out:
#        Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count         10999.000000     10999.000000         10999.000000
# mean              4.054459         2.990545           210.196836
# std               1.141490         1.413603            48.063272
# min               2.000000         1.000000            96.000000
# 25%               3.000000         2.000000           169.000000
# 50%               4.000000         3.000000           214.000000
# 75%               5.000000         4.000000           251.000000
# max               7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  \
# count     10999.000000      10999.000000   10999.000000
# mean          3.567597         13.373216    3634.016729
# std           1.522860         16.205527    1635.377251
# min           2.000000          1.000000    1001.000000
# 25%           3.000000          4.000000    1839.500000
# 50%           3.000000          7.000000    4149.000000
# 75%           4.000000         10.000000    5050.000000
# max          10.000000         65.000000    7846.000000
#
#        Reached_on_Time_Yes_No
# count            10999.000000
# mean                 0.596691
# std                  0.490584
# min                  0.000000
# 25%                  0.000000
# 50%                  1.000000
# 75%                  1.000000
# max                  1.000000

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Categorical features

# %%
# lets take categorical value "Mode of shipment" column.
d.Mode_of_Shipment.value_counts()
# Out:
# Ship      7462
# Flight    1777
# Road      1760
# Name: Mode_of_Shipment, dtype: int64

# %%
d.Mode_of_Shipment.value_counts(normalize=True).plot.barh()
plt.ylabel("Mode_of_Shipment")
plt.xlabel("Total no of couriers")
plt.title("count of different modes of shipment")
plt.show()

# %%
# lets display them in percentage.
d.Mode_of_Shipment.value_counts(normalize=True)
# Out:
# Ship      0.678425
# Flight    0.161560
# Road      0.160015
# Name: Mode_of_Shipment, dtype: float64

# %%
d.Mode_of_Shipment.value_counts(normalize=True).plot.bar()
plt.xlabel("Mode_of_Shipment")
plt.ylabel("percentage")
plt.title("Mode of shipment in Percentage")
plt.show()

# %%
#checking the no of blocks
d.Warehouse_block.value_counts()
# Out:
# F    3666
# D    1834
# A    1833
# B    1833
# C    1833
# Name: Warehouse_block, dtype: int64

# %%
#bar graph of warehouse_blocks
d.Warehouse_block.value_counts().plot.barh()
plt.xlabel("No of Couriers ordered")
plt.ylabel("Ware house blocks")
plt.title("No of couriers per block")
plt.show()

# %%
#creating a pie chart for "	Warehouse_block" columnplt.figure(figsize=(5,5))
plt.pie(d["Warehouse_block"].value_counts(), startangle=90,autopct='%.2f',labels=['F','D','A','B','C'],shadow=True)
plt.title("Percentage of products ordered from warehouse blocks")
plt.show()

# %%
d.Gender.value_counts()
# Out:
# F    5545
# M    5454
# Name: Gender, dtype: int64

# %%
sns.countplot(d.Gender)
plt.title("No of orders with respect to Gender")
plt.show()

# %%
sns.countplot(d.Reached_on_Time_Yes_No)
plt.show()

# %%
#Creating a pie chart to show the importance of products
d.Product_importance.value_counts().plot.pie()
plt.title("Product importance according to cost")
# Out:
# Text(0.5, 1.0, 'Product importance according to cost')

# %%
#Creating a pie chart to show the importance of products in percentage
plt.figure(figsize=(5,5))
plt.pie(d["Product_importance"].value_counts(), startangle=90,autopct='%.2f',labels=['low','medium','high'],shadow=True)
plt.title("Product importance according to cost in percentage")
plt.show()

# %%
sns.countplot(d.Mode_of_Shipment)
plt.title("total count of mode of shipment")
plt.show()

# %% [markdown]
#  ### Numerical features

# %%
#creating  of no of customers to cost of the products

# %%
sns.distplot(d.Cost_of_the_Product, kde=False)
plt.xlabel("Cost of the product in $")
plt.ylabel("No of costomers")
plt.show()

# %%
plt.figure(figsize=(5,5))
d['Cost_of_the_Product'].plot(kind='density')
plt.show()

# %%
sns.distplot(d.Customer_care_calls, kde=False)
plt.title(" ")
plt.show()

# %%
plt.figure(figsize=(5,5))
d['Customer_care_calls'].plot(kind='density')
plt.title("Density of customer care calls")
plt.show()

# %%
sns.distplot(d.Weight_in_gms, kde=False)
plt.xlabel("weight in grams")
plt.ylabel("No of costomers")

plt.show()

# %%
sns.distplot(d.Discount_offered, kde=False)
plt.xlabel("discount")
plt.ylabel("No of costomers")

plt.show()

# %%
sns.countplot(d.Prior_purchases)
plt.title("Total no of prior purchases ")
plt.show()

# %%
#checking the count of customer rating
d["Customer_rating"].value_counts()
# Out:
# 3    2239
# 1    2235
# 4    2189
# 5    2171
# 2    2165
# Name: Customer_rating, dtype: int64

# %%
#as the values are almost close to each other then it is better to visualize in pie chart
plt.figure(figsize=(5,5))
plt.pie(d["Customer_rating"].value_counts(), startangle=90,autopct='%.2f',labels=['3','1','4','5','2'],shadow=True)
plt.title("Customer Rating")
plt.show()

# %%
d.Cost_of_the_Product.describe()
# Out:
# count    10999.000000
# mean       210.196836
# std         48.063272
# min         96.000000
# 25%        169.000000
# 50%        214.000000
# 75%        251.000000
# max        310.000000
# Name: Cost_of_the_Product, dtype: float64

# %%
sns.boxplot(d.Cost_of_the_Product)
plt.title("Box plot for Cost of the product")
plt.show()

# %%
d.Weight_in_gms.describe()
# Out:
# count    10999.000000
# mean      3634.016729
# std       1635.377251
# min       1001.000000
# 25%       1839.500000
# 50%       4149.000000
# 75%       5050.000000
# max       7846.000000
# Name: Weight_in_gms, dtype: float64

# %%
sns.boxplot(d.Weight_in_gms)
plt.title("boxplot for weight in grams")
plt.show()

# %% [markdown]
# # Bivariate Analysis

# %%
#lets do the correlation coefficients of all numerical columns

# %%
d.corr()
# Out:
#                         Customer_care_calls  Customer_rating  \
# Customer_care_calls                1.000000         0.012209
# Customer_rating                    0.012209         1.000000
# Cost_of_the_Product                0.323182         0.009270
# Prior_purchases                    0.180771         0.013179
# Discount_offered                  -0.130750        -0.003124
# Weight_in_gms                     -0.276615        -0.001897
# Reached_on_Time_Yes_No            -0.067126         0.013119
#
#                         Cost_of_the_Product  Prior_purchases  \
# Customer_care_calls                0.323182         0.180771
# Customer_rating                    0.009270         0.013179
# Cost_of_the_Product                1.000000         0.123676
# Prior_purchases                    0.123676         1.000000
# Discount_offered                  -0.138312        -0.082769
# Weight_in_gms                     -0.132604        -0.168213
# Reached_on_Time_Yes_No            -0.073587        -0.055515
#
#                         Discount_offered  Weight_in_gms  \
# Customer_care_calls            -0.130750      -0.276615
# Customer_rating                -0.003124      -0.001897
# Cost_of_the_Product            -0.138312      -0.132604
# Prior_purchases                -0.082769      -0.168213
# Discount_offered                1.000000      -0.376067
# Weight_in_gms                  -0.376067       1.000000
# Reached_on_Time_Yes_No          0.397108      -0.268793
#
#                         Reached_on_Time_Yes_No
# Customer_care_calls                  -0.067126
# Customer_rating                       0.013119
# Cost_of_the_Product                  -0.073587
# Prior_purchases                      -0.055515
# Discount_offered                      0.397108
# Weight_in_gms                        -0.268793
# Reached_on_Time_Yes_No                1.000000

# %%
#plotting heatmap
sns.heatmap(d.corr(), cmap="Greens")
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(d.corr())
plt.show()

# %% [markdown]
# # Statistical Analysis

# %%
d.describe()
# Out:
#        Customer_care_calls  Customer_rating  Cost_of_the_Product  \
# count         10999.000000     10999.000000         10999.000000
# mean              4.054459         2.990545           210.196836
# std               1.141490         1.413603            48.063272
# min               2.000000         1.000000            96.000000
# 25%               3.000000         2.000000           169.000000
# 50%               4.000000         3.000000           214.000000
# 75%               5.000000         4.000000           251.000000
# max               7.000000         5.000000           310.000000
#
#        Prior_purchases  Discount_offered  Weight_in_gms  \
# count     10999.000000      10999.000000   10999.000000
# mean          3.567597         13.373216    3634.016729
# std           1.522860         16.205527    1635.377251
# min           2.000000          1.000000    1001.000000
# 25%           3.000000          4.000000    1839.500000
# 50%           3.000000          7.000000    4149.000000
# 75%           4.000000         10.000000    5050.000000
# max          10.000000         65.000000    7846.000000
#
#        Reached_on_Time_Yes_No
# count            10999.000000
# mean                 0.596691
# std                  0.490584
# min                  0.000000
# 25%                  0.000000
# 50%                  1.000000
# 75%                  1.000000
# max                  1.000000

# %% [markdown]
# # Multivariate Analysis

# %%
corrmat = d.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(20,15))
g=sns.heatmap(d[top_corr_features].corr(), annot =True,cmap="RdYlGn")
plt.title("Correlation matrix for all the columns")
plt.show()
#annot shows the values on the tile

# %%
# creating scatter plot to see the relation between cost of the product and the discount offered and the relation with
# whether or not th product will reach on time
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Discount_offered', y='Cost_of_the_Product', data=d, hue='Reached_on_Time_Yes_No')
plt.title("Relation between cost of the product and the discount offered and the relation with whether or not th product will reach on time")
plt.show()

# %%
#profile plot
ax = d[['Reached_on_Time_Yes_No','Customer_care_calls','Customer_rating']].plot(figsize=(20,15))
ax.legend(loc='center left', bbox_to_anchor=(0.1, 0.1));
plt.title("
          ")
plt.show()

# %%
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Discount_offered', y='Customer_care_calls', data=d, hue='Reached_on_Time_Yes_No')
plt.title("Scatterplot for customer care calls, discount offered and reached on time status")

plt.show()

# %%
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Discount_offered', y='Customer_rating', data=d, hue='Reached_on_Time_Yes_No')
plt.title("Relation between Customer rating, discount offered and reached on time status")
plt.show()

# %%
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Discount_offered', y='Prior_purchases', data=d, hue='Reached_on_Time_Yes_No')
plt.title("Scatterplot for discount offered Prior purchases and reached on time status")
plt.show()

# %%
 sns.lmplot('Customer_rating','Prior_purchases' , d, hue="Reached_on_Time_Yes_No", fit_reg=False)
plt.title("linear model plot for Prior Purchases, Reached on Time status and custtomer rating")
# Out:
# Text(0.5, 1.0, 'linear model plot for Prior Purchases, Reached on Time status and custtomer rating')

# %%
 sns.lmplot('Prior_purchases',"Reached_on_Time_Yes_No" , d, hue='Customer_rating', fit_reg=False)
plt.title("linear model plot for Prior Purchases, Reached on Time status and customer rating")
# Out:
# Text(0.5, 1.0, 'linear model plot for Prior Purchases, Reached on Time status and customer rating')

# %%
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Weight_in_gms', y='Prior_purchases', data=d, hue='Gender')
plt.title(" scatter plot for weight in grams, Prior Purchases and gender")
plt.show()

# %%
plt.figure(figsize = (15, 7))
sns.scatterplot(x='Cost_of_the_Product', y='Prior_purchases', data=d, hue='Gender')
plt.title("cost of the product, Prior purchases and Gender")
plt.show()
